# %% [markdown]
# <a href="https://colab.research.google.com/github/SudikshyaKC289/Simple-calculator-pyproject1/blob/main/MNIST_Participants.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Importing the dataset
# <hr>
# HINT: datasets has a load_digits() function

# %%
 #[STUDENT TASK 1: IMPORT THE DATASET, HINT: the datasets class has a load_digits() function]
digits = # YOUR CODE HERE
print(f"Total number of images: {len(digits.images)}")
print("Data loaded successfully!")

# %%
vsimage_index = 1

plt.figure(1, figsize=(3, 3))
plt.imshow(digits.images[image_index], cmap=plt.cm.gray_r, interpolation='nearest')
plt.title(f"Actual Label: {digits.target[image_index]}")
plt.show()

# %% [markdown]
# ## Split into train and test data
# <hr>
# HINT: use the train_test_split() function that we imported

# %%
n_samples = len(digits.images)
data = digits.images.reshape((n_samples, -1))

# [STUDENT TASK 2: SPLIT 80:20 with random state 42]
X_train, X_test, y_train, y_test = #YOUR CODE HERE

print(f"Training on {len(X_train)} images...")
print(f"Testing on {len(X_test)} images...")

# %% [markdown]
# ## Load and train the model
# <hr>
# HINT: We have imported a RandomForestClassifier model, use that<br>
# HINT2: Look into the model.fit() function for training

# %%
# [STUDENT TASK 3: CREATE THE BRAIN]
# Create a RandomForestClassifier with n_estimators=10 and random_state=42
ai_model = # YOUR CODE HERE

# [STUDENT TASK 4: TEACH THE MODEL]
# Fit the ai_model using your X_train and y_train data
# YOUR CODE HERE

print("AI Model Training Complete! 🚀")

# %% [markdown]
# ## Generate Predictions
# <hr>
# Model has a "predict" function
# and for the accuracy we have imported a function that can calculate the accuracy.

# %%
# [STUDENT TASK 5: MAKE PREDICTIONS]
# Use your ai_model to predict the answers for X_test
predictions = # YOUR CODE HERE

# [STUDENT TASK 6: GRADE THE AI]
# Calculate the accuracy_score comparing y_test to your predictions
accuracy = # YOUR CODE HERE

print(f"AI Accuracy Score: {accuracy * 100:.2f}%")
